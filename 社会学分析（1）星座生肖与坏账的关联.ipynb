# %%
import pandas as pd
import numpy as np

# %%
f = open(r'D:\风控\zodiac1.csv', encoding='utf-8')
#excel或其他文件储存最好选用CSV UTF-8这个格式，好打开
ft_zodiac = pd.read_csv(f)  
ft_zodiac.head()
# Out:
#              order_id chinese_zodiac zodiac
# 0  100000081567592000              狗    白羊座
# 1  100000467565182000              狗    金牛座
# 2  100000530945323000              狗    双子座
# 3  100000556765458000              狗    巨蟹座
# 4  100000598171623000              狗    狮子座

# %%
#查一下数据集有没有重复的order_id
len(set(ft_zodiac.order_id))
# Out:
# 43432

# %%
len(ft_zodiac.order_id)
# Out:
# 43432

# %% [markdown]
# pd15作为好坏的分割节点。>15 为坏人，<15为好人？
#
# 15天以上的人为坏，5天以内的人为好。

# %%
l = open(r'D:\风控\label.txt')
zodiac_label=pd.read_csv(l)
ft_label = zodiac_label[zodiac_label['label'] != 2]
ft_label.head()
# Out:
#              order_id  overdue_days  repay_time  label
# 0  100000081567592448             0  2018-07-09      0
# 1  100000467565182976             1  2018-07-09      0
# 2  100000530945323008             0  2018-07-09      0
# 3  100000556765458432             0  2018-07-09      0
# 4  100000598171623424             0  2018-07-09      0

# %%
data = pd.merge(ft_label,ft_zodiac,on = 'order_id',how = 'inner')
data.head()
#overdue_days历史逾期天数
# Out:
#              order_id  overdue_days  repay_time  label chinese_zodiac zodiac
# 0  100026010280960000             0  2018-07-10      0              鸡    巨蟹座
# 1  100028826231808000             0  2018-07-10      0              羊    巨蟹座
# 2  100104308499456000             0  2018-07-10      0              鸡    天蝎座
# 3  100150907216896000             0  2018-07-10      0              猴    天秤座
# 4  100152165508096000            16  2018-07-10      1              马    双鱼座

# %% [markdown]
# badrate = bad/toal

# %%
zodiac_list = set(data.zodiac)  #set()创建无序不重复元素集，可进行关系测试，删除重复数据，还可以计算交集、差集、并集等

# %%
label_list = set(data.label)

# %%
chinese_zodiac_list = set(data.chinese_zodiac)

# %%
zodiac_list
# Out:
# {'双子座',
#  '双鱼座',
#  '处女座',
#  '天秤座',
#  '天蝎座',
#  '射手座',
#  '巨蟹座',
#  '摩羯座',
#  '水瓶座',
#  '狮子座',
#  '白羊座',
#  '金牛座'}

# %%
label_list
# Out:
# {0, 1}

# %%
set(zodiac_label.label)
#2是一种灰度设置
# Out:
# {0, 1, 2}

# %%
chinese_zodiac_list
# Out:
# {'兔', '牛', '狗', '猪', '猴', '羊', '虎', '蛇', '马', '鸡', '鼠', '龙'}

# %%
#星座
zodiac_badrate = {}
for x in zodiac_list:
    
    a = data[data.zodiac == x]
    
    bad = a[a.label == 1]['label'].count()
    good = a[a.label == 0]['label'].count()
    
    zodiac_badrate[x] = bad/(bad+good)

# %%
zodiac_badrate
# Out:
# {'水瓶座': 0.125,
#  '白羊座': 0.14184397163120568,
#  '处女座': 0.14285714285714285,
#  '金牛座': 0.13157894736842105,
#  '天蝎座': 0.14035087719298245,
#  '双鱼座': 0.1282051282051282,
#  '天秤座': 0.14754098360655737,
#  '摩羯座': 0.13333333333333333,
#  '狮子座': 0.13,
#  '巨蟹座': 0.10526315789473684,
#  '双子座': 0.125,
#  '射手座': 0.08270676691729323}

# %%
f = zip(zodiac_badrate.keys(),zodiac_badrate.values())
f = sorted(f,key = lambda x : x[1],reverse = True )
zodiac_badrate = pd.DataFrame(f)
zodiac_badrate.columns = pd.Series(['星座','badrate'])
zodiac_badrate
# Out:
#      星座   badrate
# 0   天秤座  0.147541
# 1   处女座  0.142857
# 2   白羊座  0.141844
# 3   天蝎座  0.140351
# 4   摩羯座  0.133333
# 5   金牛座  0.131579
# 6   狮子座  0.130000
# 7   双鱼座  0.128205
# 8   水瓶座  0.125000
# 9   双子座  0.125000
# 10  巨蟹座  0.105263
# 11  射手座  0.082707

# %%
#from pyecharts.charts import Line
#import pyecharts.options as opts
#from pyecharts.faker import Faker

# %%
#line1=(
    Line() # 生成line类型图表
    .add_xaxis(xaxis_data = zodiac_badrate['星座'] )  # 添加x轴，Faker.choose()是使用faker的随机数据生成x轴标签
    .add_yaxis('badrate',zodiac_badrate['badrate'])  # 添加y轴，Faker.values()是使用faker的随机数据生成y轴数值
    .set_global_opts(title_opts=opts.TitleOpts(title='星座'))
)
line1.render('pyecharts-line.html') # 生成一个名为pyecharts-line.html的网页文件，打开网页就是下图

#原文链接：https://blog.csdn.net/weixin_44146276/article/details/102705998
# Out:
# 'C:\\Users\\Lenovo\\pyecharts-line.html'

# %%
#安装老版pychart line
#pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pyecharts==0.5.11
from pyecharts import Line
x = zodiac_badrate['星座']
y = zodiac_badrate['badrate']
line = Line('星座')
line.add(1,x,y)
#一般差距几倍以上才会有效，途中这种差距很小，表明星座和坏账没什么关系
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="135fe5d9ee164c3884c700a1cb8f49a6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_135fe5d9ee164c3884c700a1cb8f49a6 = echarts.init(document.getElementById('135fe5d9ee164c3884c700a1cb8f49a6'), 'light', {renderer: 'canvas'});
#
# var option_135fe5d9ee164c3884c700a1cb8f49a6 = {
#     "title": [
#         {
#             "text": "\u661f\u5ea7",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 43985,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": 1,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u5929\u79e4\u5ea7",
#                     0.14754098360655737
#                 ],
#                 [
#                     "\u5904\u5973\u5ea7",
#                     0.14285714285714285
#                 ],
#                 [
#                     "\u767d\u7f8a\u5ea7",
#                     0.14184397163120568
#                 ],
#                 [
#                     "\u5929\u874e\u5ea7",
#                     0.14035087719298245
#                 ],
#                 [
#                     "\u6469\u7faf\u5ea7",
#                     0.13333333333333333
#                 ],
#                 [
#                     "\u91d1\u725b\u5ea7",
#                     0.13157894736842105
#                 ],
#                 [
#                     "\u72ee\u5b50\u5ea7",
#                     0.13
#                 ],
#                 [
#                     "\u53cc\u9c7c\u5ea7",
#                     0.1282051282051282
#                 ],
#                 [
#                     "\u6c34\u74f6\u5ea7",
#                     0.125
#                 ],
#                 [
#                     "\u53cc\u5b50\u5ea7",
#                     0.125
#                 ],
#                 [
#                     "\u5de8\u87f9\u5ea7",
#                     0.10526315789473684
#                 ],
#                 [
#                     "\u5c04\u624b\u5ea7",
#                     0.08270676691729323
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 43985
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 1
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u5929\u79e4\u5ea7",
#                 "\u5904\u5973\u5ea7",
#                 "\u767d\u7f8a\u5ea7",
#                 "\u5929\u874e\u5ea7",
#                 "\u6469\u7faf\u5ea7",
#                 "\u91d1\u725b\u5ea7",
#                 "\u72ee\u5b50\u5ea7",
#                 "\u53cc\u9c7c\u5ea7",
#                 "\u6c34\u74f6\u5ea7",
#                 "\u53cc\u5b50\u5ea7",
#                 "\u5de8\u87f9\u5ea7",
#                 "\u5c04\u624b\u5ea7"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_135fe5d9ee164c3884c700a1cb8f49a6.setOption(option_135fe5d9ee164c3884c700a1cb8f49a6);
#
#     });
# </script>

# %%
#生肖
chinese_zodiac_badrate = {}
for x in chinese_zodiac_list:
    
    a = data[data.chinese_zodiac == x]
    
    bad = a[a.label == 1]['label'].count() #选取每个星座对应的label这一列的坏人个数
    good = a[a.label == 0]['label'].count()
    
    chinese_zodiac_badrate[x] = bad/(bad+good)

# %%
c = a[a.label == 1].count()

# %%
c
# Out:
# order_id          12
# overdue_days      12
# repay_time        12
# label             12
# chinese_zodiac    12
# zodiac            12
# dtype: int64

# %%
d = a[a.label == 1]['label'].count()

# %%
d
# Out:
# 12

# %%
chinese_zodiac_badrate
# Out:
# {'鸡': 0.11494252873563218,
#  '鼠': 0.07692307692307693,
#  '羊': 0.10465116279069768,
#  '蛇': 0.1559633027522936,
#  '龙': 0.13333333333333333,
#  '牛': 0.1323529411764706,
#  '虎': 0.11864406779661017,
#  '马': 0.1497005988023952,
#  '兔': 0.13529411764705881,
#  '猴': 0.14814814814814814,
#  '猪': 0.08108108108108109,
#  '狗': 0.13636363636363635}

# %%
f = zip(chinese_zodiac_badrate.keys(),chinese_zodiac_badrate.values()) #zip()将对象中对应的元素打包成一个个元组
f = sorted(f,key = lambda x : x[1],reverse = True )#对badrate进行排序
chinese_zodiac_badrate = pd.DataFrame(f)
chinese_zodiac_badrate.columns = pd.Series(['生肖','badrate'])
chinese_zodiac_badrate
# Out:
#    生肖   badrate
# 0   蛇  0.155963
# 1   马  0.149701
# 2   猴  0.148148
# 3   狗  0.136364
# 4   兔  0.135294
# 5   龙  0.133333
# 6   牛  0.132353
# 7   虎  0.118644
# 8   鸡  0.114943
# 9   羊  0.104651
# 10  猪  0.081081
# 11  鼠  0.076923

# %%
chinese_zodiac_badrate.keys()
# Out:
# Index(['生肖', 'badrate'], dtype='object')

# %%
chinese_zodiac_badrate.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-367f56e6360d> in <module>()
# ----> 1 chinese_zodiac_badrate.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
x = chinese_zodiac_badrate['生肖']
y = chinese_zodiac_badrate['badrate']
line = Line('生肖')
line.add(1,x,y)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f6f78e8e1110458dad58392a58fbd189" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f6f78e8e1110458dad58392a58fbd189 = echarts.init(document.getElementById('f6f78e8e1110458dad58392a58fbd189'), 'light', {renderer: 'canvas'});
#
# var option_f6f78e8e1110458dad58392a58fbd189 = {
#     "title": [
#         {
#             "text": "\u751f\u8096",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1259409,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": 1,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u86c7",
#                     0.1559633027522936
#                 ],
#                 [
#                     "\u9a6c",
#                     0.1497005988023952
#                 ],
#                 [
#                     "\u7334",
#                     0.14814814814814814
#                 ],
#                 [
#                     "\u72d7",
#                     0.13636363636363635
#                 ],
#                 [
#                     "\u5154",
#                     0.13529411764705881
#                 ],
#                 [
#                     "\u9f99",
#                     0.13333333333333333
#                 ],
#                 [
#                     "\u725b",
#                     0.1323529411764706
#                 ],
#                 [
#                     "\u864e",
#                     0.11864406779661017
#                 ],
#                 [
#                     "\u9e21",
#                     0.11494252873563218
#                 ],
#                 [
#                     "\u7f8a",
#                     0.10465116279069768
#                 ],
#                 [
#                     "\u732a",
#                     0.08108108108108109
#                 ],
#                 [
#                     "\u9f20",
#                     0.07692307692307693
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1259409
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 1
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u86c7",
#                 "\u9a6c",
#                 "\u7334",
#                 "\u72d7",
#                 "\u5154",
#                 "\u9f99",
#                 "\u725b",
#                 "\u864e",
#                 "\u9e21",
#                 "\u7f8a",
#                 "\u732a",
#                 "\u9f20"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_f6f78e8e1110458dad58392a58fbd189.setOption(option_f6f78e8e1110458dad58392a58fbd189);
#
#     });
# </script>
